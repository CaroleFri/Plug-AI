# %% [markdown]
# # Plug-AI : Training a model

# %% [markdown]
# ## Config file

# %%
# %%writefile config_training_demo.yaml
# # Default config is used even if no config file is specified in CLI. Undefined arguments will take the default values.
# ##################################################################################################
# ####################################### Global arguments : #######################################
# ##################################################################################################
# config_file: null
# export_config: null
# mode: TRAINING
# verbose: FULL
# seed: null
# export_dir: /gpfswork/rech/ibu/commun/Demo_BraTS_SegResNet_300523
# ##################################################################################################
# ######################################## Data arguments : ########################################
# ##################################################################################################
# dataset: BraTS
# dataset_kwargs:
#     dataset_dir: /gpfswork/rech/ibu/commun/BraTS2021/BraTS2021_Training_Data/
#     download_dataset: false
#     transformation: BraTS_transform
# train_ratio: 0.9
# val_ratio: 0.1
# batch_size: 3
# shuffle: true
# drop_last: false
# limit_sample: 20 #null or int, use it if you want to debug with short training
# ##################################################################################################
# ####################################### Model arguments : ########################################
# ##################################################################################################
# model: SegResNet
# model_kwargs:
#     blocks_down: [1, 2, 2, 4]
#     blocks_up: [1, 1, 1]
#     init_filters: 16
#     in_channels: 4
#     out_channels: 3
#     dropout_prob: 0.2
# #model_weights_path: null # Use it if you want to restart training from a checkpoint
# ##################################################################################################
# ##################################### Execution arguments : ######################################
# ##################################################################################################
# #Training settings
# nb_epoch: 2
# device: cuda
# random_seed: 2022  # None for real randomness, set an integer for reproductibility
# report_log: False
#
# loop: Default
#
# optimizer: AdamW
# optimizer_kwargs:
#     lr: 1e-4
#     weight_decay: 1e-5
# lr_scheduler: null
# lr_scheduler_kwargs:
#     T_max: 2
#
# criterion: DiceCELoss
# criterion_kwargs:
#     sigmoid: True
#
# metric: null
# metric_kwargs:
#     sigmoid: True
# Out:
# Overwriting config_training_demo.yaml

# %% [markdown]
# ## Execution

# %%
# !python -m plug_ai --config_file config_training_demo.yaml
# Out:
# /gpfsdswork/projects/rech/ibu/ssos023/Plug-AI/examples/config_training_demo.yaml
# Plug-AI given kwargs:
# 	 dataset : BraTS
# 	 dataset_kwargs : {'dataset_dir': '/gpfswork/rech/ibu/commun/BraTS2021/BraTS2021_Training_Data/', 'download_dataset': False, 'transformation': 'BraTS_transform'}
# 	 limit_sample : 20
# 	 preprocess : None
# 	 preprocess_kwargs : None
# 	 model : SegResNet
# 	 model_kwargs : {'blocks_down': [1, 2, 2, 4], 'blocks_up': [1, 1, 1], 'init_filters': 16, 'in_channels': 4, 'out_channels': 3, 'dropout_prob': 0.2}
# 	 model_weights_path : None
# 	 nb_epoch : 2
# 	 learning_rate : 5e-05
# 	 device : cuda
# 	 random_seed : 2022
# 	 report_log : False
# 	 loop : Default
# 	 loop_kwargs : None
# 	 optimizer : AdamW
# 	 optimizer_kwargs : {'lr': 0.0001, 'weight_decay': 1e-05}
# 	 lr_scheduler : None
# 	 lr_scheduler_kwargs : {'T_max': 2}
# 	 criterion : DiceCELoss
# 	 criterion_kwargs : {'sigmoid': True}
# 	 metric : MeanDice
# 	 metric_kwargs : {'sigmoid': True}
# 	 config_file : config_training_demo.yaml
# 	 export_config : None
# 	 mode : TRAINING
# 	 verbose : FULL
# 	 seed : None
# 	 export_dir : /gpfswork/rech/ibu/commun/Demo_BraTS_SegResNet_300523
# 	 train_ratio : 0.9
# 	 val_ratio : 0.1
# 	 batch_size : 3
# 	 shuffle : True
# 	 drop_last : False
# ==================================== Dataset initialization ... ====================================
# Running with interpreted config:
#  	dataset: BraTS
# 	dataset_kwargs: {'dataset_dir': '/gpfswork/rech/ibu/commun/BraTS2021/BraTS2021_Training_Data/', 'download_dataset': False, 'transformation': 'BraTS_transform'}
# 	preprocess: None
# 	preprocess_kwargs: {}
# 	mode: TRAINING
# 	batch_size: 3
# 	train_ratio: 0.9
# 	val_ratio: 0.1
# 	limit_sample: 20
# 	shuffle: True
# 	drop_last: False
# 	seed: None
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/Demo_BraTS_SegResNet_300523
# Dataset type is valid
# loading dataset...
# Datalist extact with:  1252  items
# Dataset keys: ['data_id', 'channel_0', 'channel_1', 'channel_2', 'channel_3', 'label']
# BraTS
# <class 'monai.data.dataset.Dataset'>
# Loaded the dataset
# Using  20 elements of the full Dataset.
# Train, Val, Test sizes :  17 1 2
# ===================================== Model initialization ... =====================================
# Running with interpreted config:
#  	model: SegResNet
# 	model_kwargs: {'blocks_down': [1, 2, 2, 4], 'blocks_up': [1, 1, 1], 'init_filters': 16, 'in_channels': 4, 'out_channels': 3, 'dropout_prob': 0.2}
# 	model_weights_path: None
# 	device: cuda
# 	mode: TRAINING
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/Demo_BraTS_SegResNet_300523
# 	model_name: SegResNet
# Model type is valid
# Model preparation done!
# =================================== Execution initialization ... ===================================
# Running with interpreted config:
#  	loop: <class 'plug_ai.runners.trainer.Default_Trainer'>
# 	loop_kwargs: {}
# 	mode: TRAINING
# 	nb_epoch: 2
# 	device: cuda
# 	seed: None
# 	report_log: False
# 	criterion: <class 'monai.losses.dice.DiceCELoss'>
# 	metric: <class 'monai.metrics.meandice.DiceMetric'>
# 	criterion_kwargs: {'sigmoid': True}
# 	metric_kwargs: {'sigmoid': True}
# 	optimizer: <class 'torch.optim.adamw.AdamW'>
# 	optimizer_kwargs: {'lr': 0.0001, 'weight_decay': 1e-05}
# 	lr_scheduler: {'scheduler': None, 'scheduler_update': None}
# 	lr_scheduler_kwargs: {'T_max': 2}
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/Demo_BraTS_SegResNet_300523
# 	dataset_manager: <plug_ai.managers.managers.DatasetManager object at 0x154a1baa89a0>
# 	model_manager: <plug_ai.managers.managers.ModelManager object at 0x154b4bc93040>
# TRAINING MODE :
# dict_keys(['metric', 'device', 'criterion', 'optimizer_kwargs', 'model', 'val_loader', 'optimizer', 'metric_kwargs', 'nb_epoch', 'criterion_kwargs', 'export_dir', 'lr_scheduler_kwargs', 'train_loader', 'verbose', 'lr_scheduler'])
# Training ...
# Criterion is : DiceCELoss(
#   (dice): DiceLoss()
#   (cross_entropy): CrossEntropyLoss()
# )
# Metric is : <monai.metrics.meandice.DiceMetric object at 0x154a1ba16bb0>
# Optimizer is : AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 1e-05
# )
# Learning Rate Scheduler is : None
# start training loop, 6 steps per epoch
# /linkhome/idris/genidr/ssos023/.local/lib/python3.9/site-packages/monai/losses/dice.py:708: UserWarning: Multichannel targets are not supported in this older Pytorch version 1.10.0a0+git302ee7b. Using argmax (as a workaround) to convert target to a single channel.
#   warnings.warn(
# [Epoch 1/2 |  Step_Epoch 1/6 | Loss 1.8217226266860962]
# [Epoch 1/2 |  Step_Epoch 2/6 | Loss 1.5174670219421387]
# [Epoch 1/2 |  Step_Epoch 3/6 | Loss 1.3801265954971313]
# [Epoch 1/2 |  Step_Epoch 4/6 | Loss 1.327462911605835]
# [Epoch 1/2 |  Step_Epoch 5/6 | Loss 1.2772215604782104]
# [Epoch 1/2 |  Step_Epoch 6/6 | Loss 1.2589155435562134]
# Best model saved at epoch 0 with validation loss 1.253
# [Step_Eval 1/1]
# Evaluation score for this epoch: tensor([0.0052])
# Epoch 0 finished
# [Epoch 2/2 |  Step_Epoch 1/6 | Loss 1.2405447959899902]
# [Epoch 2/2 |  Step_Epoch 2/6 | Loss 1.244530200958252]
# [Epoch 2/2 |  Step_Epoch 3/6 | Loss 1.2371101379394531]
# [Epoch 2/2 |  Step_Epoch 4/6 | Loss 1.2378085851669312]
# [Epoch 2/2 |  Step_Epoch 5/6 | Loss 1.240525245666504]
# [Epoch 2/2 |  Step_Epoch 6/6 | Loss 1.2336719036102295]
# Best model saved at epoch 1 with validation loss 1.237
# [Step_Eval 1/1]
# Evaluation score for this epoch: tensor([0.0051])
# Epoch 1 finished
# Execution over
# >>> Complete execution in: 0:01:21.535351

# %% [markdown]
# ## Experimenting on a new set of parameters

# %%
# !python -m plug_ai --config_file config_training_demo.yaml --export_dir /gpfswork/rech/ibu/commun/TestAdam --optimizer Adam
# Out:
# /gpfsdswork/projects/rech/ibu/ssos023/Plug-AI/examples/config_training_demo.yaml
# Plug-AI given kwargs:
# 	 dataset : BraTS
# 	 dataset_kwargs : {'dataset_dir': '/gpfswork/rech/ibu/commun/BraTS2021/BraTS2021_Training_Data/', 'download_dataset': False, 'transformation': 'BraTS_transform'}
# 	 limit_sample : 20
# 	 preprocess : None
# 	 preprocess_kwargs : None
# 	 model : SegResNet
# 	 model_kwargs : {'blocks_down': [1, 2, 2, 4], 'blocks_up': [1, 1, 1], 'init_filters': 16, 'in_channels': 4, 'out_channels': 3, 'dropout_prob': 0.2}
# 	 model_weights_path : None
# 	 nb_epoch : 2
# 	 learning_rate : 5e-05
# 	 device : cuda
# 	 random_seed : 2022
# 	 report_log : False
# 	 loop : Default
# 	 loop_kwargs : None
# 	 optimizer : Adam
# 	 optimizer_kwargs : {'lr': 0.0001, 'weight_decay': 1e-05}
# 	 lr_scheduler : None
# 	 lr_scheduler_kwargs : {'T_max': 2}
# 	 criterion : DiceCELoss
# 	 criterion_kwargs : {'sigmoid': True}
# 	 metric : None
# 	 metric_kwargs : {'sigmoid': True}
# 	 config_file : config_training_demo.yaml
# 	 export_config : None
# 	 mode : TRAINING
# 	 verbose : FULL
# 	 seed : None
# 	 export_dir : /gpfsdswork/projects/rech/ibu/commun/TestAdam
# 	 train_ratio : 0.9
# 	 val_ratio : 0.1
# 	 batch_size : 3
# 	 shuffle : True
# 	 drop_last : False
# ==================================== Dataset initialization ... ====================================
# Running with interpreted config:
#  	dataset: BraTS
# 	dataset_kwargs: {'dataset_dir': '/gpfswork/rech/ibu/commun/BraTS2021/BraTS2021_Training_Data/', 'download_dataset': False, 'transformation': 'BraTS_transform'}
# 	preprocess: None
# 	preprocess_kwargs: {}
# 	mode: TRAINING
# 	batch_size: 3
# 	train_ratio: 0.9
# 	val_ratio: 0.1
# 	limit_sample: 20
# 	shuffle: True
# 	drop_last: False
# 	seed: None
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/TestAdam
# Dataset type is valid
# loading dataset...
# Datalist extact with:  1252  items
# Dataset keys: ['data_id', 'channel_0', 'channel_1', 'channel_2', 'channel_3', 'label']
# BraTS
# <class 'monai.data.dataset.Dataset'>
# Loaded the dataset
# Using  20 elements of the full Dataset.
# Train, Val, Test sizes :  17 1 2
# ===================================== Model initialization ... =====================================
# Running with interpreted config:
#  	model: SegResNet
# 	model_kwargs: {'blocks_down': [1, 2, 2, 4], 'blocks_up': [1, 1, 1], 'init_filters': 16, 'in_channels': 4, 'out_channels': 3, 'dropout_prob': 0.2}
# 	model_weights_path: None
# 	device: cuda
# 	mode: TRAINING
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/TestAdam
# 	model_name: SegResNet
# Model type is valid
# Model preparation done!
# =================================== Execution initialization ... ===================================
# Running with interpreted config:
#  	loop: <class 'plug_ai.runners.trainer.Default_Trainer'>
# 	loop_kwargs: {}
# 	mode: TRAINING
# 	nb_epoch: 2
# 	device: cuda
# 	seed: None
# 	report_log: False
# 	criterion: <class 'monai.losses.dice.DiceCELoss'>
# 	metric: None
# 	criterion_kwargs: {'sigmoid': True}
# 	metric_kwargs: {'sigmoid': True}
# 	optimizer: <class 'torch.optim.adam.Adam'>
# 	optimizer_kwargs: {'lr': 0.0001, 'weight_decay': 1e-05}
# 	lr_scheduler: {'scheduler': None, 'scheduler_update': None}
# 	lr_scheduler_kwargs: {'T_max': 2}
# 	verbose: FULL
# 	export_dir: /gpfsdswork/projects/rech/ibu/commun/TestAdam
# 	dataset_manager: <plug_ai.managers.managers.DatasetManager object at 0x146b34ad8760>
# 	model_manager: <plug_ai.managers.managers.ModelManager object at 0x146b34ad88b0>
# TRAINING MODE :
# dict_keys(['criterion_kwargs', 'export_dir', 'optimizer_kwargs', 'nb_epoch', 'optimizer', 'criterion', 'device', 'verbose', 'metric_kwargs', 'model', 'lr_scheduler', 'metric', 'val_loader', 'train_loader', 'lr_scheduler_kwargs'])
# Training ...
# Criterion is : DiceCELoss(
#   (dice): DiceLoss()
#   (cross_entropy): CrossEntropyLoss()
# )
# Metric is : None
# Optimizer is : Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 1e-05
# )
# Learning Rate Scheduler is : None
# start training loop, 6 steps per epoch
# /linkhome/idris/genidr/ssos023/.local/lib/python3.9/site-packages/monai/losses/dice.py:708: UserWarning: Multichannel targets are not supported in this older Pytorch version 1.10.0a0+git302ee7b. Using argmax (as a workaround) to convert target to a single channel.
#   warnings.warn(
# [Epoch 1/2 |  Step_Epoch 1/6 | Loss 2.082733154296875]
# [Epoch 1/2 |  Step_Epoch 2/6 | Loss 1.8634095191955566]
# [Epoch 1/2 |  Step_Epoch 3/6 | Loss 1.7334437370300293]
# [Epoch 1/2 |  Step_Epoch 4/6 | Loss 1.6228225231170654]
# [Epoch 1/2 |  Step_Epoch 5/6 | Loss 1.6110316514968872]
# [Epoch 1/2 |  Step_Epoch 6/6 | Loss 1.5802652835845947]
# Best model saved at epoch 0 with validation loss 1.596
# Epoch 0 finished
# [Epoch 2/2 |  Step_Epoch 1/6 | Loss 1.568551778793335]
# [Epoch 2/2 |  Step_Epoch 2/6 | Loss 1.574528455734253]
# ^C
